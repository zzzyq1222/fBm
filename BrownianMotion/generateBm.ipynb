# %%
import utils
import cholesky_defactorization as cd
import random_walk as rw

# %%
bmr = rw.BMRandomWalk()
bmcd = cd.BMCholeskyFac()

# %%
paths = 100
interval = 0.001
timespan = 10

# %%
# random walks
n_rw_paths = bmr.generateNBM(paths, timespan, interval)  # data
utils.draw_bm_paths(paths, timespan, interval, n_rw_paths)

# %%
# cholesky defactorization
n_cd_paths = bmcd.generateNBM(paths, timespan, interval)  # data
utils.draw_bm_paths(paths, timespan, interval, n_cd_paths)
